# %%
import torch
import cv2
from PIL import Image
from IPython.display import display

# %%
# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
path = 'D:/EducationalStuff/MastersDS/HisThesis/AllDataSets/CustomizedData/SingleImages/toys.jpg'
# Load image
img = Image.open(path)
display(img)

# Run inference on the image
results = model(img)
# Print the detected objects and their confidence scores
print(results.pandas().xyxy[0])

# Save the image with the detected objects
#results.save()
# Out:
# Using cache found in C:\Users\Computers Way/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-4-15 Python-3.11.2 torch-2.0.0+cpu CPU
#
# Fusing layers...
# requirements: C:\Users\Computers Way\.cache\torch\hub\requirements.txt not found, check failed.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=241x209>
#          xmin        ymin        xmax        ymax  confidence  class  \
# 0  109.200546   71.586975  153.714355  125.736267    0.831414     67
# 1   19.793329  136.525116   77.315224  186.267502    0.609025     31
# 2  139.473694  140.312302  178.829880  179.147583    0.478437     67
#
#          name
# 0  cell phone
# 1   snowboard
# 2  cell phone
